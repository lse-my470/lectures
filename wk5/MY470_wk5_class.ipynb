# %% [markdown]
# ### MY470 Computer Programming
# # Programming in Teams
# ### Week 5 Lab, MT 2017

# %% [markdown]
# ## GitHub as a Collaboration Tool

# %% [markdown]
# ##

# %%
def double_one(a):
    return 2*a
